# %% [markdown]
# # 250-row rolling feature construction
# This notebook demonstrates the exact current past-only feature construction.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent))
from src.data.loading import load_dataset, clean_dataset
from src.features.rolling_features import add_past_only_rolling_features, rolling_feature_names
df_raw=load_dataset(Path("../data/raw/dataset.xlsx"))
df,_=clean_dataset(df_raw)
df_roll=add_past_only_rolling_features(df,"Age",250)
roll_cols=rolling_feature_names(250)
df_roll[roll_cols].head()

# %% [markdown]
# The implementation uses `shift(1)` before the 250-row rolling mean/std, so the current row is excluded.
