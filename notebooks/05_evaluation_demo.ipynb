# %% [markdown]
# # Evaluation outputs
# Load the machine-readable metrics and validation predictions produced by `train.py`.

# %%
import pandas as pd, json
from pathlib import Path
root=Path("..")
print(json.dumps(json.loads((root/"results/metrics/legacy_random_split.json").read_text()), indent=2))
pred=pd.read_csv(root/"results/predictions/legacy_random_split_validation_predictions.csv")
pred.head()
